# %%
import pandas as pd
import seaborn as sns
import matplotlib as mplstyle
import matplotlib.pyplot as plt
sns.set(style="whitegrid")

# %matplotlib inline

# %%
schools = pd.read_csv("campus_crime.csv")

# %%
print(schools)
# Out:
#                               instname  total_enr  murder  manslaughter  \
# 0               American River College      95250       0             0
# 1             Arizona State University     289016       0             0
# 2                   Ashford University      74596       0             0
# 3                    Auburn University      25469       0             0
# 4    Austin Community College District    1082400       0             0
# ..                                 ...        ...     ...           ...
# 223             Wayne State University     123060       0             0
# 224             Weber State University      25301       0             0
# 225           West Virginia University      29617       0             0
# 226        Western Kentucky University     126216       0             0
# 227        Western Michigan University     250860       0             0
#
#      forcible  nonforce  robbery  agg_aslt  burglary  vehicle  arson
# ...

# %%
schools.head(10)
# Out:
#                                          instname  total_enr  murder  \
# 0                          American River College      95250       0
# 1                        Arizona State University     289016       0
# 2                              Ashford University      74596       0
# 3                               Auburn University      25469       0
# 4               Austin Community College District    1082400       0
# 5                           Ball State University      44294       0
# 6                               Boston University      64878       0
# 7                  Brigham Young University-Provo     170505       0
# 8                                 Broward College     379782       0
# 9  California State Polytechnic University-Pomona      21107       0
#
#    manslaughter  forcible  nonforce  robbery  agg_aslt  burglary  vehicle  \
# 0             0         1         2        3         2         6        8
# ...

# %%
schools.describe()
# Out:
#           total_enr      murder  manslaughter    forcible    nonforce  \
# count  2.280000e+02  228.000000    228.000000  228.000000  228.000000
# mean   1.082848e+05    0.021930      0.004386    3.995614    0.048246
# std    1.537517e+05    0.174224      0.066227    5.210543    0.234373
# min    2.016000e+04    0.000000      0.000000    0.000000    0.000000
# 25%    2.949325e+04    0.000000      0.000000    0.000000    0.000000
# 50%    5.477800e+04    0.000000      0.000000    2.000000    0.000000
# 75%    1.227450e+05    0.000000      0.000000    5.250000    0.000000
# max    1.323315e+06    2.000000      1.000000   30.000000    2.000000
#
#           robbery    agg_aslt    burglary     vehicle       arson
# count  228.000000  228.000000  228.000000  228.000000  228.000000
# mean     1.728070    2.583333   23.793860    6.052632    0.820175
# std      2.383072    3.545436   25.235744    8.105409    1.686468
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# ...

# %%
schools["burglary"]
# Out:
# 0       6
# 1      90
# 2       1
# 3      22
# 4       2
#        ..
# 223    18
# 224    11
# 225    22
# 226    32
# 227    13
# Name: burglary, Length: 228, dtype: int64

# %%
grid_columns = ["total_enr", "murder", "manslaughter", "forcible", "nonforce", "robbery", "agg_aslt", "burglary", "vehicle", "arson"]

g = sns.PairGrid(schools[grid_columns])

g.map_offdiag(plt.scatter)

# %%
schools["forcible"].sum()
# Out:
# 911

# %%
schools["robbery"].sum()
# Out:
# 394

# %%
schools["agg_aslt"].sum()
# Out:
# 589

# %%
schools["burglary"].sum()
# Out:
# 5425

# %%
schools["vehicle"].sum()
# Out:
# 1380

# %%
schools["burglary"]
# Out:
# 0       6
# 1      90
# 2       1
# 3      22
# 4       2
#        ..
# 223    18
# 224    11
# 225    22
# 226    32
# 227    13
# Name: burglary, Length: 228, dtype: int64

# %%
plt.figure(figsize=(100,50))
bar= sns.barplot(x="instname", y="burglary", data=schools)

# %%
print("Story ideas: 1.Burglary is the most common crime in these schools, with 5425 cases. The second common crime is about vehicles. Find out why and what students and school administration can do to deal with this issue. 2. Find out schools with the most burglaries and check their safety efforts. 3.Two schools with high burglaries also have high arsons. Identify the schools and see what happened in the past.")
# Out:
# Story ideas: 1.Burglary is the most common crime in these schools, with 5425 cases. The second common crime is about vehicles. Find out why and what students and school administration can do to deal with this issue. 2. Find out schools with the most burglaries and check their safety efforts. 3.Two schools with high burglaries also have high arsons. Identify the schools and see what happened in the past.
